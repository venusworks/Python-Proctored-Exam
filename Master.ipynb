# %% [markdown]
# # Live Proctored Python Certification Exam

# %% [markdown]
# ## Exam Structure

# %% [markdown]
# * Duration of exam : 50 mins
# * Sections: MCQs & Practical
#
# ### Time and Marks distribution of each section
#
# * MCQs : Max Marks - 40 ; Time allotted - 20 min
# * Practical: Max Marks - 60 ; Time allotted - 30 min

# %% [markdown]
# ## Exam guidelines
#
# * Multiple Choice questions will be answered in Google form. No negative marking so attempt all questions.
# * Out of the three practical questions provided, attempt any two.
# * All quesitons should be done in front of invigilator, i.e, you will be sharing your screen for monitoring.
# * Both Video and audio should be on during the test.
# * Practical file need to be uploaded at the end of examination via the site specified.
#
# ### All the best !!!

# %% [markdown]
# ### -------------------------------------Question Paper--------------------------------------

# %% [markdown]
# #### Section 1 : MCQs

# %% [markdown]
# * Click here to [start](https://forms.gle/heQQUG8FgZRnrggWA)

# %% [markdown]
# #### Section 2 : Practical

# %% [markdown]
# Q1. Write a program that reads a positive integer, n, from the user and then displays the
# sum of all of the integers from 1 to n. The sum of the first n positive integers can be
# computed using the formula:   sum = (n)*(n + 1) / 2
#
# * Fill the below ..... space with valid code

# %%
n = input(.....)

sum_of_n_integers = .....

Print(...)

# %% [markdown]
# Sample output:
#     n = 5
#     sum = 15

# %% [markdown]
# Q2. A prime number is an integer greater than one that is only divisible by one and itself.
# Write a function that determines whether or not its parameter is prime, returning
# True if it is, and False otherwise. Write a main program that reads an integer
# from the user and displays a message indicating whether or not it is prime.

# %%
def Isprime(n):
   
    # Check each number from 2 up to but not including n to see if it divides evenly into n
    ....
    
n = input(....)

if Isprime(n):
    .....
else:
    .....

# %% [markdown]
# Sample Output:
# n = 7
#
# 7 is prime number

# %% [markdown]
# Q3. A string is a palindrome if it is identical forward and backward. For example “anna”,
# “civic”, “level” and “hannah” are all examples of palindromicwords. Write a program
# that reads a string from the user and uses a loop to determine whether or not it is a
# palindrome. Display the result, including a meaningful output message.

# %%
line = input(....)
# Assume that it is a palindrome until we can prove otherwise
is_palindrome = True
......


if is_palindrome:
print(line, "is a palindrome")
else:
print(line, "is not a palindrome")

# %% [markdown]
# Sample Output:
#   * line = Hindi
#   * Hindi is not a palindrome
